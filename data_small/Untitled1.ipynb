# %%
import pandas as pd

# %%
df=pd.read_csv("data_small/TG_STAID000001.txt",skiprows=22,parse_date=["    DATE"])

# %%
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 print(df)
#
# NameError: name 'df' is not defined

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
import pandas as pd
df=pd.read_csv("TG_STAID000001.txt",skiprows=20,parse_dates=["    DATE"])

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 59316      1   35381 2022-05-27  -9999      9
# 59317      1   35381 2022-05-28  -9999      9
# 59318      1   35381 2022-05-29  -9999      9
# 59319      1   35381 2022-05-30  -9999      9
# 59320      1   35381 2022-05-31  -9999      9
#
# [59321 rows x 5 columns]

# %% [markdown]
# # load the data frame

# %%
df[10:20]
# Out:
#     STAID   SOUID       DATE     TG   Q_TG
# 10      1   35381 1860-01-11     -5      0
# 11      1   35381 1860-01-12    -18      0
# 12      1   35381 1860-01-13    -27      0
# 13      1   35381 1860-01-14    -26      0
# 14      1   35381 1860-01-15    -37      0
# 15      1   35381 1860-01-16     -9      0
# 16      1   35381 1860-01-17      7      0
# 17      1   35381 1860-01-18     -6      0
# 18      1   35381 1860-01-19    -16      0
# 19      1   35381 1860-01-20    -19      0

# %%
df[100:230]
# Out:
#      STAID   SOUID       DATE     TG   Q_TG
# 100      1   35381 1860-04-10     36      0
# 101      1   35381 1860-04-11     35      0
# 102      1   35381 1860-04-12     25      0
# 103      1   35381 1860-04-13     14      0
# 104      1   35381 1860-04-14     34      0
# ..     ...     ...        ...    ...    ...
# 225      1   35381 1860-08-13    137      0
# 226      1   35381 1860-08-14    141      0
# 227      1   35381 1860-08-15    138      0
# 228      1   35381 1860-08-16    156      0
# 229      1   35381 1860-08-17    179      0
#
# [130 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['STAID', ' SOUID', '    DATE', '   TG', ' Q_TG'], dtype='object')

# %% [markdown]
# # Simple Statistics and filtering

# %%
df.loc[df['   TG']!=-9999]
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 53655      1   35381 2006-11-26     80      0
# 53656      1   35381 2006-11-27     70      0
# 53657      1   35381 2006-11-28     71      0
# 53658      1   35381 2006-11-29     63      0
# 53659      1   35381 2006-11-30     84      0
#
# [53103 rows x 5 columns]

# %%
df.loc[df['   TG']!=-9999]['   TG']
# Out:
# 0        21
# 1        46
# 2        31
# 3        37
# 4        31
#          ..
# 53655    80
# 53656    70
# 53657    71
# 53658    63
# 53659    84
# Name:    TG, Length: 53103, dtype: int64

# %%
df.loc[df['   TG']!=-9999]['   TG'].mean()/10
# Out:
# 6.360787526128467

# %%
df.loc[df['   TG']!=-9999]['   TG'].max()/10
# Out:
# 26.2

# %%
df.loc[df['   TG']!=-9999]['   TG'].min()/10
# Out:
# -28.8

# %%
df.loc[df['   TG']!=-9999]['   TG'].hist()
# Out:
# <AxesSubplot:>

# %%
df.loc[df['   TG']==df['   TG'].max()]
# Out:
#       STAID   SOUID       DATE     TG   Q_TG
# 3150      1   35381 1868-08-16    262      0

# %%
df.loc[df['   TG']==df['   TG'].max()]['   DATE'].squueze()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '   DATE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.loc[df['   TG']==df['   TG'].max()]
# Out:
#       STAID   SOUID       DATE     TG   Q_TG
# 3150      1   35381 1868-08-16    262      0

# %%
df.loc[34,'   TG']
# Out:
# -5

# %% [markdown]
# # adding new coloumn

# %%
import numpy as np
df["TG1"]=df['   TG'].mask(df['   TG']==-9999,np.nan)

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   TG1
# 0          1   35381 1860-01-01     21      0  21.0
# 1          1   35381 1860-01-02     46      0  46.0
# 2          1   35381 1860-01-03     31      0  31.0
# 3          1   35381 1860-01-04     37      0  37.0
# 4          1   35381 1860-01-05     31      0  31.0
# ...      ...     ...        ...    ...    ...   ...
# 59316      1   35381 2022-05-27  -9999      9   NaN
# 59317      1   35381 2022-05-28  -9999      9   NaN
# 59318      1   35381 2022-05-29  -9999      9   NaN
# 59319      1   35381 2022-05-30  -9999      9   NaN
# 59320      1   35381 2022-05-31  -9999      9   NaN
#
# [59321 rows x 6 columns]

# %%
df["TG2"]=df['   TG']/10
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   TG1    TG2
# 0          1   35381 1860-01-01     21      0  21.0    2.1
# 1          1   35381 1860-01-02     46      0  46.0    4.6
# 2          1   35381 1860-01-03     31      0  31.0    3.1
# 3          1   35381 1860-01-04     37      0  37.0    3.7
# 4          1   35381 1860-01-05     31      0  31.0    3.1
# ...      ...     ...        ...    ...    ...   ...    ...
# 59316      1   35381 2022-05-27  -9999      9   NaN -999.9
# 59317      1   35381 2022-05-28  -9999      9   NaN -999.9
# 59318      1   35381 2022-05-29  -9999      9   NaN -999.9
# 59319      1   35381 2022-05-30  -9999      9   NaN -999.9
# 59320      1   35381 2022-05-31  -9999      9   NaN -999.9
#
# [59321 rows x 7 columns]

# %%
df["Fahrenheit"]=df["TG1"]*(9/5)+32

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   TG1    TG2  Fahrenheit
# 0          1   35381 1860-01-01     21      0  21.0    2.1        69.8
# 1          1   35381 1860-01-02     46      0  46.0    4.6       114.8
# 2          1   35381 1860-01-03     31      0  31.0    3.1        87.8
# 3          1   35381 1860-01-04     37      0  37.0    3.7        98.6
# 4          1   35381 1860-01-05     31      0  31.0    3.1        87.8
# ...      ...     ...        ...    ...    ...   ...    ...         ...
# 59316      1   35381 2022-05-27  -9999      9   NaN -999.9         NaN
# 59317      1   35381 2022-05-28  -9999      9   NaN -999.9         NaN
# 59318      1   35381 2022-05-29  -9999      9   NaN -999.9         NaN
# 59319      1   35381 2022-05-30  -9999      9   NaN -999.9         NaN
# 59320      1   35381 2022-05-31  -9999      9   NaN -999.9         NaN
#
# [59321 rows x 8 columns]
